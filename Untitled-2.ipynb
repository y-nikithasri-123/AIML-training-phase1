# %%
print("Nikitha")
# Out:
# Nikitha

# %%
import pandas as pd 
import numpy as np
s=pd.Series([1,2,3,4,5])
print("pandas series:",s)
data=np.array(['a','b','c','d'])
s=pd.Series(data)
print("pandas series:",s)
# Out:
# pandas series: 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# pandas series: 0    a
# 1    b
# 2    c
# 3    d
# dtype: str
