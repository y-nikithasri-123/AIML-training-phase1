# %%
a=input("enter value of a:")
b=input("enter value of b:")
temp=a
a=b
b=temp
print("a="+a)
print("b="+b)
# Out:
# a=3
# b=2

# %%
name=input("what is your name?")
print(name)
length=len(name)
print(length)
# Out:
# Nikitha
# 7

# %%
Name=input("Enter your name:")
print("Hello",Name)
print("Hey"+" "+input("what is your name?")+","+"how are you?")
print("I'm fine")
# Out:
# Hello Nikitha
# Hey Nikitha,how are you?
# I'm fine

# %%
print("Helloworld\nHelloworld\nHelloworld")
print("Nikitha"+"sri")
print("Nikitha"+" "+"sri"+"IAS")
# Out:
# Helloworld
# Helloworld
# Helloworld
# Nikithasri
# Nikitha sriIAS

# %%
print("first program-python print function")
print("it is declared like this")
print('print("what to print")')
print("print('what to print')")
# Out:
# first program-python print function
# it is declared like this
# print("what to print")
# print('what to print')
