# %% [markdown]
# line plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {'Name': ['THULASI', 'DEEPU', 'PRASAD', 'NIKITHA'], 'Age': [21, 23, 20, 24]}
df = pd.DataFrame(data)

sns.lineplot(x=df.index, y='Age', data=df)
plt.xlabel('Index')
plt.ylabel('Age')
plt.title('Age Line Plot')
plt.show()

# %% [markdown]
# scatter plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {'Name': ['THULASI', 'DEEPU', 'PRASAD', 'NIKITHA'], 'Age': [21, 23, 20, 24]}
df = pd.DataFrame(data)

sns.scatterplot(x=df.index, y='Age', data=df)
plt.show()

# %% [markdown]
# box pot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {'Name': ['THULASI', 'DEEPU', 'PRASAD', 'NIKITHA'], 'Age': [21, 23, 20, 45]} 
df = pd.DataFrame(data)

sns.boxplot(y='Age', data=df)
plt.show()

# %% [markdown]
# violin plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {'Name': ['THULASI', 'DEEPU', 'PRASAD', 'NIKITHA'], 'Age': [21, 23, 20, 24]}
df = pd.DataFrame(data)

sns.violinplot(y='Age', data=df)
plt.show()

# %% [markdown]
# swarm plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = {'Name': ['THULASI', 'DEEPU', 'PRASAD', 'NIKITHA'], 'Age': [21, 23, 20, 24]}
df = pd.DataFrame(data)

sns.swarmplot(x=df.index, y='Age', data=df)
plt.show()

# %% [markdown]
# bar plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {'Name': ['THULASI', 'DEEPU', 'PRASAD', 'NIKITHA'], 'Age': [21, 23, 20, 24]}
df = pd.DataFrame(data)

sns.barplot(x='Name', y='Age', data=df)
plt.show()

# %% [markdown]
# point plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {'Name': ['THULASI', 'DEEPU', 'PRASAD', 'NIKITHA'],'Age': [21, 23, 20, 24]}
df = pd.DataFrame(data)

sns.pointplot(x='Name', y='Age', data=df)
plt.show()

# %% [markdown]
# count plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {'Name': ['ANSH', 'SAHIL', 'ANSH', 'JAYAN', 'ANURAG', 'ANURAG', 'ANURAG', 'SAHIL']}
df = pd.DataFrame(data)

sns.countplot(x='Name', data=df)
plt.title("Frequency of Names")
plt.show()

# %% [markdown]
# kde plot

# %%
from sklearn.datasets import load_iris
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['Species'] = iris.target
df['Species'] = df['Species'].map({ 0: 'Setosa', 1: 'Versicolor', 2: 'Virginica'})

sns.kdeplot(data=df[df['Species'] == 'Virginica'], x='sepal length (cm)', fill=True, label='Virginica')
plt.legend()
plt.show()
